# %% [markdown]
# <a href="https://colab.research.google.com/github/HananAlfares/Enhanced-Intrusion-Detection-for-IoT/blob/main/Bot_IoT_combine_data_secnarious.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount("/content/drive/")
# Set working directory (consider running this again after mounting)
cwd = "/content/drive/My Drive/Intrusion analysis and incident management/Bot_IoT"
os.chdir(cwd)
# Out:
# Mounted at /content/drive/

# %%
# Data preprocessing
import pandas as pd
import numpy as np

# %%
data_names=pd.read_csv("data_names.csv")

# %%
data_names.head()
# Out:
# Empty DataFrame
# Columns: [pkSeqID, stime, flgs, proto, saddr, sport, daddr, dport, pkts, bytes, state, ltime, seq, dur, mean, stddev, smac, dmac, sum, min, max, soui, doui, sco, dco, spkts, dpkts, sbytes, dbytes, rate, srate, drate, attack, category, subcategory ]
# Index: []
#
# [0 rows x 35 columns]

# %%
data1=pd.read_csv("data_1.csv",low_memory=False)

# %%
data1.head()
# Out:
#    pkSeqID         stime flgs proto            saddr  sport           daddr  \
# 0        1  1.526344e+09    e   arp    192.168.100.1    NaN   192.168.100.3
# 1        2  1.526344e+09    e   tcp    192.168.100.7    139   192.168.100.4
# 2        3  1.526344e+09    e   udp  192.168.100.149  51838  27.124.125.250
# 3        4  1.526344e+09    e   arp    192.168.100.4    NaN   192.168.100.7
# 4        5  1.526344e+09    e   udp   192.168.100.27  58999   192.168.100.1
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes       rate     srate  \
# 0    NaN     4    240  ...     2      2     120     120   0.002508  0.000836
# 1  36390    10    680  ...     5      5     350     330   0.006190  0.002751
# 2    123     2    180  ...     1      1      90      90  20.590960  0.000000
# 3    NaN    10    510  ...     5      5     210     300   0.006189  0.002751
# 4     53     4    630  ...     2      2     174     456   0.005264  0.001755
#
#       drate  attack  category  subcategory
# ...

# %%
data2=pd.read_csv("data_2.csv",low_memory=False)

# %%
data2.head()
# Out:
#    pkSeqID         stime flgs proto            saddr  sport          daddr  \
# 0  1000001  1.526949e+09    e   tcp  192.168.100.150  49731  192.168.100.3
# 1  1000002  1.526949e+09    e   tcp  192.168.100.150  49731  192.168.100.3
# 2  1000003  1.526949e+09    e   tcp  192.168.100.150  49731  192.168.100.3
# 3  1000004  1.526949e+09    e   tcp  192.168.100.150  49731  192.168.100.3
# 4  1000005  1.526949e+09    e   tcp  192.168.100.150  49731  192.168.100.3
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes       rate  srate  \
# 0  41081     2    120  ...     1      1      60      60  23.862932    0.0
# 1  13371     2    120  ...     1      1      60      60  23.868057    0.0
# 2   3796     2    120  ...     1      1      60      60  23.868057    0.0
# 3  63993     2    120  ...     1      1      60      60  23.860085    0.0
# 4  27356     2    120  ...     1      1      60      60  23.868628    0.0
#
#    drate  attack        category  subcategory
# ...

# %%
data3=pd.read_csv("data_3.csv",low_memory=False)

# %%
data3.head()

# %%
data4=pd.read_csv("data_4.csv",low_memory=False)

# %%
data4.head()
# Out:
#    pkSeqID         stime flgs proto            saddr    sport          daddr  \
# 0  3000001  1.528082e+09  e s   tcp  192.168.100.149  54919.0  192.168.100.5
# 1  3000002  1.528082e+09  e s   tcp  192.168.100.149  54920.0  192.168.100.5
# 2  3000003  1.528082e+09  e s   tcp  192.168.100.149  54921.0  192.168.100.5
# 3  3000004  1.528082e+09  e s   tcp  192.168.100.149  54924.0  192.168.100.5
# 4  3000005  1.528082e+09  e s   tcp  192.168.100.149  54925.0  192.168.100.5
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     3    462  ...     3      0     462       0  0.046877  0.046877
# 1   80.0     3    462  ...     3      0     462       0  0.046877  0.046877
# 2   80.0     3    462  ...     3      0     462       0  0.046877  0.046877
# 3   80.0     3    462  ...     3      0     462       0  0.046877  0.046877
# 4   80.0     3    462  ...     3      0     462       0  0.046877  0.046877
#
#    drate  attack  category  subcategory
# ...

# %%
data5=pd.read_csv("data_5.csv",low_memory=False)

# %%
data5.head()
# Out:
#    pkSeqID         stime flgs proto            saddr    sport          daddr  \
# 0  4000001  1.528082e+09  e s   tcp  192.168.100.148  56307.0  192.168.100.6
# 1  4000002  1.528082e+09  e s   tcp  192.168.100.148  56310.0  192.168.100.6
# 2  4000003  1.528082e+09  e s   tcp  192.168.100.148  56311.0  192.168.100.6
# 3  4000004  1.528082e+09  e s   tcp  192.168.100.148  56312.0  192.168.100.6
# 4  4000005  1.528082e+09  e s   tcp  192.168.100.148  56313.0  192.168.100.6
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     4    522  ...     3      1     462      60  0.076991  0.051328
# 1   80.0     4    522  ...     3      1     462      60  0.076991  0.051328
# 2   80.0     4    522  ...     3      1     462      60  0.076991  0.051328
# 3   80.0     4    522  ...     3      1     462      60  0.076991  0.051328
# 4   80.0     4    522  ...     3      1     462      60  0.076991  0.051328
#
#    drate  attack  category  subcategory
# ...

# %%
data6=pd.read_csv("data_6.csv",low_memory=False)

# %%
data6.head()
# Out:
#    pkSeqID         stime flgs proto            saddr    sport          daddr  \
# 0  5000001  1.528082e+09  e g   tcp  192.168.100.150  52526.0  192.168.100.3
# 1  5000002  1.528082e+09  e g   tcp  192.168.100.150  52527.0  192.168.100.3
# 2  5000003  1.528082e+09  e g   tcp  192.168.100.150  52528.0  192.168.100.3
# 3  5000004  1.528082e+09  e g   tcp  192.168.100.150  52529.0  192.168.100.3
# 4  5000005  1.528082e+09  e g   tcp  192.168.100.150  52532.0  192.168.100.3
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     6    548  ...     4      2     428     120  0.181202  0.108721
# 1   80.0     6    548  ...     4      2     428     120  0.181202  0.108721
# 2   80.0     6    548  ...     4      2     428     120  0.181202  0.108721
# 3   80.0     6    548  ...     4      2     428     120  0.181202  0.108721
# 4   80.0     6    548  ...     4      2     428     120  0.181202  0.108721
#
#       drate  attack  category  subcategory
# ...

# %%
data7=pd.read_csv("data_7.csv",low_memory=False)

# %%
data7.head()
# Out:
#    pkSeqID         stime flgs proto            saddr    sport          daddr  \
# 0  6000001  1.528082e+09  e s   tcp  192.168.100.147  37439.0  192.168.100.6
# 1  6000002  1.528082e+09  e s   tcp  192.168.100.147  37440.0  192.168.100.6
# 2  6000003  1.528082e+09  e s   tcp  192.168.100.147  37441.0  192.168.100.6
# 3  6000004  1.528082e+09  e s   tcp  192.168.100.147  37448.0  192.168.100.6
# 4  6000005  1.528082e+09  e s   tcp  192.168.100.147  37449.0  192.168.100.6
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     3    462  ...     3      0     462       0  0.051491  0.051491
# 1   80.0     3    462  ...     3      0     462       0  0.051491  0.051491
# 2   80.0     3    462  ...     3      0     462       0  0.051491  0.051491
# 3   80.0     4    522  ...     3      1     462      60  0.077237  0.051492
# 4   80.0     4    522  ...     3      1     462      60  0.077237  0.051492
#
#    drate  attack  category  subcategory
# ...

# %%
data8=pd.read_csv("data_8.csv",low_memory=False)

# %%
data8.head()
# Out:
#    pkSeqID         stime flgs proto            saddr    sport          daddr  \
# 0  7000001  1.528082e+09  e g   tcp  192.168.100.149  17608.0  192.168.100.3
# 1  7000002  1.528082e+09  e g   tcp  192.168.100.149  17609.0  192.168.100.3
# 2  7000003  1.528082e+09  e g   tcp  192.168.100.149  17612.0  192.168.100.3
# 3  7000004  1.528082e+09  e g   tcp  192.168.100.149  17613.0  192.168.100.3
# 4  7000005  1.528082e+09  e g   tcp  192.168.100.149  17618.0  192.168.100.3
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     9    822  ...     6      3     642     180  0.155749  0.097343
# 1   80.0     9    822  ...     6      3     642     180  0.155749  0.097343
# 2   80.0     9    822  ...     6      3     642     180  0.155749  0.097343
# 3   80.0     9    822  ...     6      3     642     180  0.155628  0.097268
# 4   80.0     9    822  ...     6      3     642     180  0.155628  0.097268
#
#       drate  attack  category  subcategory
# ...

# %%
data9=pd.read_csv("data_9.csv",low_memory=False)

# %%
data9.head()
# Out:
#    pkSeqID         stime flgs proto            saddr   sport          daddr  \
# 0  8000001  1.528083e+09  e g   tcp  192.168.100.149  7564.0  192.168.100.3
# 1  8000002  1.528083e+09  e g   tcp  192.168.100.149  7565.0  192.168.100.3
# 2  8000003  1.528083e+09  e g   tcp  192.168.100.149  7570.0  192.168.100.3
# 3  8000004  1.528083e+09  e g   tcp  192.168.100.149  7571.0  192.168.100.3
# 4  8000005  1.528083e+09  e g   tcp  192.168.100.149  7574.0  192.168.100.3
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     6    548  ...     4      2     428     120  0.212465  0.127479
# 1   80.0     6    548  ...     4      2     428     120  0.212465  0.127479
# 2   80.0     6    548  ...     4      2     428     120  0.212465  0.127479
# 3   80.0     6    548  ...     4      2     428     120  0.212465  0.127479
# 4   80.0     6    548  ...     4      2     428     120  0.212465  0.127479
#
#       drate  attack  category  subcategory
# ...

# %%
data10=pd.read_csv("data_10.csv",low_memory=False)

# %%
data10.head()
# Out:
#    pkSeqID         stime flgs proto            saddr   sport          daddr  \
# 0  9000001  1.528083e+09  e s   tcp  192.168.100.150  5712.0  192.168.100.6
# 1  9000002  1.528083e+09  e s   tcp  192.168.100.150  5713.0  192.168.100.6
# 2  9000003  1.528083e+09  e s   tcp  192.168.100.150  5594.0  192.168.100.6
# 3  9000004  1.528083e+09  e s   tcp  192.168.100.150  5595.0  192.168.100.6
# 4  9000005  1.528083e+09  e s   tcp  192.168.100.150  5598.0  192.168.100.6
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0   80.0     4    616  ...     4      0     616       0  0.050914  0.050914
# 1   80.0     4    616  ...     4      0     616       0  0.050914  0.050914
# 2   80.0     6    736  ...     4      2     616     120  0.084802  0.050914
# 3   80.0     6    736  ...     4      2     616     120  0.084802  0.050914
# 4   80.0     6    736  ...     4      2     616     120  0.084802  0.050914
#
#       drate  attack  category  subcategory
# ...

# %%
# combine all secnarious and then preprocess the data
combined_data = pd.concat([data1, data2, data3,data4,data5], ignore_index=True)

# %%
combined_data.head()
# Out:
#    pkSeqID         stime flgs proto            saddr  sport           daddr  \
# 0        1  1.526344e+09    e   arp    192.168.100.1    NaN   192.168.100.3
# 1        2  1.526344e+09    e   tcp    192.168.100.7    139   192.168.100.4
# 2        3  1.526344e+09    e   udp  192.168.100.149  51838  27.124.125.250
# 3        4  1.526344e+09    e   arp    192.168.100.4    NaN   192.168.100.7
# 4        5  1.526344e+09    e   udp   192.168.100.27  58999   192.168.100.1
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes       rate     srate  \
# 0    NaN     4    240  ...     2      2     120     120   0.002508  0.000836
# 1  36390    10    680  ...     5      5     350     330   0.006190  0.002751
# 2    123     2    180  ...     1      1      90      90  20.590960  0.000000
# 3    NaN    10    510  ...     5      5     210     300   0.006189  0.002751
# 4     53     4    630  ...     2      2     174     456   0.005264  0.001755
#
#       drate  attack  category  subcategory
# ...

# %%
# to convert dataframe to csv file which we will use in our classification
combined_data.to_csv('Bot_IoT_combined.csv', index=False)

# %%
#  the combined data saved into drive
